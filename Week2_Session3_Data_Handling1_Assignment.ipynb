# %% [markdown]
# <a href="https://colab.research.google.com/github/rahmotganiu-hub/ACCESS-SAP-Data-Science-Track/blob/main/Week2_Session3_Data_Handling1_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_sales = pd.read_csv("/content/Warehouse_and_Retail_Sales.csv")

# %%
#head(): first 3 rows of this dataset#
df_sales.head(3)
# Out:
#    YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0  2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1  2020      1                          PWSWN INC    100024
# 2  2020      1            RELIABLE CHURCHILL LLLP      1001
#
#                       ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                  BOOTLEG RED - 750ML      WINE           0.0
# 1            MOMENT DE PLAISIR - 750ML      WINE           0.0
# 2  S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER           0.0
#
#    RETAIL TRANSFERS  WAREHOUSE SALES
# 0               0.0              2.0
# 1               1.0              4.0
# 2               0.0              1.0

# %%
#tail(): first 3 rows of this dataset#
#there is nothing unusual#
df_sales.tail()
# Out:
#         YEAR  MONTH                     SUPPLIER ITEM CODE  \
# 307640  2020      9                  LEGENDS LTD     99753
# 307641  2020      9           ANHEUSER BUSCH INC      9997
# 307642  2020      9  COASTAL BREWING COMPANY LLC     99970
# 307643  2020      9      BOSTON BEER CORPORATION     99990
# 307644  2020      9                          NaN        WC
#
#                                ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 307640         DUTCHESS DE BOURGOGNE NR - 750ML      BEER          0.00
# 307641                  HOEGAARDEN 4/6NR - 12OZ      BEER         66.12
# 307642  DOMINION OAK BARREL STOUT 4/6 NR - 12OZ      BEER          2.25
# 307643         SAM ADAMS SUMMER VARIETY 12PK NR      BEER         20.50
# 307644                              WINE CREDIT       REF          0.00
#
#         RETAIL TRANSFERS  WAREHOUSE SALES
# 307640               0.0             5.00
# 307641              37.0           240.75
# 307642               0.0             0.00
# ...

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307645 entries, 0 to 307644
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   YEAR              307645 non-null  int64
#  1   MONTH             307645 non-null  int64
#  2   SUPPLIER          307478 non-null  object
#  3   ITEM CODE         307645 non-null  object
#  4   ITEM DESCRIPTION  307645 non-null  object
#  5   ITEM TYPE         307644 non-null  object
#  6   RETAIL SALES      307642 non-null  float64
#  7   RETAIL TRANSFERS  307645 non-null  float64
#  8   WAREHOUSE SALES   307645 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 21.1+ MB

# %%
df_sales.describe()
# Out:
#                 YEAR          MONTH   RETAIL SALES  RETAIL TRANSFERS  \
# count  307645.000000  307645.000000  307642.000000     307645.000000
# mean     2018.438525       6.423862       7.024071          6.936465
# std         1.083061       3.461812      30.986238         30.237195
# min      2017.000000       1.000000      -6.490000        -38.490000
# 25%      2017.000000       3.000000       0.000000          0.000000
# 50%      2019.000000       7.000000       0.320000          0.000000
# 75%      2019.000000       9.000000       3.267500          3.000000
# max      2020.000000      12.000000    2739.000000       1990.830000
#
#        WAREHOUSE SALES
# count    307645.000000
# mean         25.294597
# std         249.916798
# min       -7800.000000
# 25%           0.000000
# 50%           1.000000
# 75%           5.000000
# max       18317.000000

# %%
df_sales.columns
# Out:
# Index(['YEAR', 'MONTH', 'SUPPLIER', 'ITEM CODE', 'ITEM DESCRIPTION',
#        'ITEM TYPE', 'RETAIL SALES', 'RETAIL TRANSFERS', 'WAREHOUSE SALES'],
#       dtype='object')

# %% [markdown]
# selecting columns

# %%
#Selecting any two numerical columns and display them#
df_sales.loc[:, ['YEAR','RETAIL TRANSFERS']]
# Out:
#         YEAR  RETAIL TRANSFERS
# 0       2020               0.0
# 1       2020               1.0
# 2       2020               0.0
# 3       2020               0.0
# 4       2020               0.0
# ...      ...               ...
# 307640  2020               0.0
# 307641  2020              37.0
# 307642  2020               0.0
# 307643  2020               0.0
# 307644  2020               0.0
#
# [307645 rows x 2 columns]

# %%
#Selecting any two categorical columns and display them.#
df_sales.loc[:, ['ITEM TYPE','SUPPLIER']]
# Out:
#        ITEM TYPE                           SUPPLIER
# 0           WINE  REPUBLIC NATIONAL DISTRIBUTING CO
# 1           WINE                          PWSWN INC
# 2           BEER            RELIABLE CHURCHILL LLLP
# 3           WINE          LANTERNA DISTRIBUTORS INC
# 4           WINE               DIONYSOS IMPORTS INC
# ...          ...                                ...
# 307640      BEER                        LEGENDS LTD
# 307641      BEER                 ANHEUSER BUSCH INC
# 307642      BEER        COASTAL BREWING COMPANY LLC
# 307643      BEER            BOSTON BEER CORPORATION
# 307644       REF                                NaN
#
# [307645 rows x 2 columns]

# %% [markdown]
# Filtering Rows

# %%
#Filter rows using one condition#
df_sales[df_sales['YEAR']< 2020]
# Out:
#         YEAR  MONTH                   SUPPLIER ITEM CODE  \
# 34701   2017      6      CONSTANTINE WINES INC    100008
# 34702   2017      6    INTERBALT PRODUCTS CORP    100012
# 34703   2017      6                   DOPS INC     10004
# 34704   2017      6  LANTERNA DISTRIBUTORS INC    100145
# 34705   2017      6            ROYAL WINE CORP    100200
# ...      ...    ...                        ...       ...
# 296063  2019     11                        NaN        BC
# 296064  2019     11                        NaN        WC
# 296065  2019     11   JACK POUST & COMPANY INC     82630
# 296066  2019     11         E & J GALLO WINERY     83431
# 296067  2019     11         E & J GALLO WINERY     84012
#
#                                     ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 34701            AMITY VINEYARDS P/NOIR 2013 - 750ML      WINE          0.00
# 34702                            PAPI P/GRIG - 750ML      WINE          0.00
# ...

# %%
#Filter rows using two conditions#
df_sales.loc[(df_sales['MONTH'] > 9) & (df_sales['RETAIL SALES'] >= 13.13)]
# Out:
#         YEAR  MONTH                        SUPPLIER ITEM CODE  \
# 88378   2017     10              JIM BEAM BRANDS CO     10197
# 88379   2017     10       STE MICHELLE WINE ESTATES    101974
# 88413   2017     10                 BACARDI USA INC     10332
# 88429   2017     10  JACKSON FAMILY ENTERPRISES INC     10413
# 88431   2017     10   BUCK DISTRIBUTING COMPANY INC     10430
# ...      ...    ...                             ...       ...
# 296034  2019     11                   CROWN IMPORTS     99201
# 296054  2019     11          TROEGS BREWING COMPANY     99706
# 296055  2019     11        SIERRA NEVADA BREWING CO     99708
# 296061  2019     11              ANHEUSER BUSCH INC      9997
# 296066  2019     11              E & J GALLO WINERY     83431
#
#                              ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 88378   KNOB CREEK BOURBON 9YR - 100P - 1.75L    LIQUOR         43.75
# 88379               CH ST MICH P/GRIS - 750ML      WINE         26.61
# ...

# %%
#Display only 2–3 selected columns for those rows#
df_sales.loc[
    (df_sales['MONTH'] > 9) & (df_sales['RETAIL SALES'] >= 13.13),df_sales.columns[:3]
]
# Out:
#         YEAR  MONTH                        SUPPLIER
# 88378   2017     10              JIM BEAM BRANDS CO
# 88379   2017     10       STE MICHELLE WINE ESTATES
# 88413   2017     10                 BACARDI USA INC
# 88429   2017     10  JACKSON FAMILY ENTERPRISES INC
# 88431   2017     10   BUCK DISTRIBUTING COMPANY INC
# ...      ...    ...                             ...
# 296034  2019     11                   CROWN IMPORTS
# 296054  2019     11          TROEGS BREWING COMPANY
# 296055  2019     11        SIERRA NEVADA BREWING CO
# 296061  2019     11              ANHEUSER BUSCH INC
# 296066  2019     11              E & J GALLO WINERY
#
# [7952 rows x 3 columns]

# %%
#The first 5 rows and first 3 columns#
df_sales.iloc[:5, :3]
# Out:
#    YEAR  MONTH                           SUPPLIER
# 0  2020      1  REPUBLIC NATIONAL DISTRIBUTING CO
# 1  2020      1                          PWSWN INC
# 2  2020      1            RELIABLE CHURCHILL LLLP
# 3  2020      1          LANTERNA DISTRIBUTORS INC
# 4  2020      1               DIONYSOS IMPORTS INC

# %%
#Rows 10–20 and columns 2–4#
df_sales.iloc[10:21,1:5]
# Out:
#     MONTH                              SUPPLIER ITEM CODE  \
# 10      1          HEAVEN HILL DISTILLERIES INC     10120
# 11      1                 BACCHUS IMPORTERS LTD     10123
# 12      1                 BACCHUS IMPORTERS LTD     10124
# 13      1                 BACCHUS IMPORTERS LTD     10125
# 14      1             MONSIEUR TOUTON SELECTION    101346
# 15      1  THE COUNTRY VINTNER, LLC DBA WINEBOW    101486
# 16      1  THE COUNTRY VINTNER, LLC DBA WINEBOW    101532
# 17      1                       ROYAL WINE CORP    101664
# 18      1     REPUBLIC NATIONAL DISTRIBUTING CO    101702
# 19      1                       ROYAL WINE CORP    101753
# 20      1                       ROYAL WINE CORP    101915
#
#                           ITEM DESCRIPTION
# 10           J W DANT BOURBON 100P - 1.75L
# 11  NOTEWORTHY SMALL BATCH BOURBON - 750ML
# 12        NOTEWORTHY SMALL BATCH RYE 750ML
# 13    NOTEWORTHY SMALL BATCH HONEY BBN 750
# 14              ALSACE WILLIAM GEW - 750ML
# ...

# %% [markdown]
# Grouping & Aggregation

# %%
df_sales.groupby("ITEM DESCRIPTION").size()
# Out:
# ITEM DESCRIPTION
# ! EA ! - 750ML                                     3
# 1 ROSE A DAY ROSE - 1L                             4
# 1+1=3 CYGNUS BRUT NATURE RESA CAVA ORG - 750ML     7
# 10 BARREL JOE IPA 1/6K                            18
# 10 BARREL JOE IPA 4/6PK NR                        17
#                                                   ..
# ZYWIEC 4/6 16.9OZ CAN                             23
# ZYWIEC 4/6NR - 11.2OZ                             24
# ZYWIEC PORTER 16.9 OZ                             15
# ZYWIEC PORTER 4/6 NR                               3
# ZYWIEC PORTER 5/4 NR - 16.9OZ                      4
# Length: 34822, dtype: int64

# %%
#Calculate the total of a numerical column for each category.#
df_sales.groupby("ITEM DESCRIPTION")["RETAIL SALES"].sum()
# Out:
# ITEM DESCRIPTION
# ! EA ! - 750ML                                      0.00
# 1 ROSE A DAY ROSE - 1L                              0.00
# 1+1=3 CYGNUS BRUT NATURE RESA CAVA ORG - 750ML      0.00
# 10 BARREL JOE IPA 1/6K                              0.00
# 10 BARREL JOE IPA 4/6PK NR                        107.54
#                                                    ...
# ZYWIEC 4/6 16.9OZ CAN                              40.85
# ZYWIEC 4/6NR - 11.2OZ                              17.25
# ZYWIEC PORTER 16.9 OZ                              27.85
# ZYWIEC PORTER 4/6 NR                                0.00
# ZYWIEC PORTER 5/4 NR - 16.9OZ                       1.00
# Name: RETAIL SALES, Length: 34822, dtype: float64

# %%
#multiple metrics#
df_sales.groupby("ITEM DESCRIPTION").agg({
    "RETAIL SALES":['sum','mean','max','count'],
    "MONTH":['sum','mean','max','count'],
    "ITEM CODE":['count'], # 'mean', 'sum', and 'max' are not meaningful for item codes#
    })
# Out:
#                                                RETAIL SALES                   \
#                                                         sum      mean    max
# ITEM DESCRIPTION
# ! EA ! - 750ML                                         0.00  0.000000   0.00
# 1 ROSE A DAY ROSE - 1L                                 0.00  0.000000   0.00
# 1+1=3 CYGNUS BRUT NATURE RESA CAVA ORG - 750ML         0.00  0.000000   0.00
# 10 BARREL JOE IPA 1/6K                                 0.00  0.000000   0.00
# 10 BARREL JOE IPA 4/6PK NR                           107.54  6.325882  15.50
# ...                                                     ...       ...    ...
# ZYWIEC 4/6 16.9OZ CAN                                 40.85  1.776087   3.80
# ZYWIEC 4/6NR - 11.2OZ                                 17.25  0.718750   2.50
# ZYWIEC PORTER 16.9 OZ                                 27.85  1.856667   3.75
# ZYWIEC PORTER 4/6 NR                                   0.00  0.000000   0.00
# ...
